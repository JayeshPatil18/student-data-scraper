# %%
import http.client

conn = http.client.HTTPSConnection('www.linkedin.com')
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
    'accept-language': 'en-US,en;q=0.5',
    'cache-control': 'max-age=0',
    'cookie': 'bcookie="v=2&d7459408-8b22-45d3-8247-116d498c7c51"; bscookie="v=1&20240615133656176adc41-b832-4cd7-8306-6934d63c0209AQFAl0gVR7KTzWvcPQE6UcqlmpbtSdd4"; JSESSIONID="ajax:7068959739132267645"; dfpfpt=c9ea6e0520d747a0b8e036ad617e8f0a; timezone=Asia/Calcutta; li_theme=light; li_theme_set=app; li_theme_set=app; lang=v=2&lang=en-us; fptctx2=taBcrIH61PuCVH7eNCyH0FFaWZWIHTJWSYlBtG47cVsJgQsHp3pdqX632Q2%252fGw8EEbFatRvRFj5PmHZcmKf2NHgoqycpbt1uJBhEDISA6c%252bktSvdImn4FwpG%252bxAbJNOIFeoKOH1OU9ozSaDqgPBKi2xY0tOHRv2bFbPLM2yAv1jNSw1Ljxyl3Cazobb43DMb5gkw%252f52Y2kjJjTZLfWwWWoMm4TPPQcnHS%252fI%252fChT4VLdpihQXwItHUFLZqVeDZpmvcOw7B8cOC2%252bYp9xtvXW2gLrD8pchDHJKPuxwgCeMMXjiKpr%252byuhX0RlozD6c89z0YU8Zvde4I4R%252bHSbcQG3Wa6h5cgnrlcdai6cSQjW4FXg%253d; fid=AQGfXYy6R42BdQAAAZD50PC9OqArSiQX1NW1Lg_GwUppWHHIvscuGASFXLFI3r5-pxwORJMoSnB1WQ; li_at=AQEDATqwURIBD8Z3AAABkPnRlhUAAAGRHd4aFU0ALdMCzxRiU33TbWVX4wdJGxFduTgJfbTPawSrJpfdkZYD5Kj-GEqJbJpulhYMzM3gFqL1MyX4lKEje0ohwmP_SMS1LwZkGEZTzwuIhFFEKl02C5hp; liap=true; lidc="b=VB18:s=V:r=V:a=V:p=V:g=5096:u=679:x=1:i=1722178181:t=1722261080:v=2:sig=AQH7Kst6vZ2BmNl83fTN5qLW0-u82XAS"; UserMatchHistory=AQIwRMO6HaxoQwAAAZD69yzTxtTV3h-wynqitlkaePkSP5oBIjg-0u5jMaEHnr7WgbR92F75IxgWkVeIA09wk-3kTbPvvULV0-X1DZB1y6kMpWZsC_WAmOJZzj0i6Ya4udbhpCobvVp6-sXfVzdIGNgvSV-1agFwXEUJNg9I9twQp8OcbIW_PRkZ_KfA-ALlAXSB3KTdAIhM1Ee7485TFJnAqteyovGavqrlFC1-4kleKq7GVnErygE9i1bNpusU_wvl8GULhSnxw8TT7TeNgYdY4U6HBVe6uRe6CLvB0LZeYd1Mg9HmaAZ0_xGDURm7APvrxWQc5SH1dJJK7kVu',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Not)A;Brand";v="99", "Brave";v="127", "Chromium";v="127"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'sec-gpc': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Mobile Safari/537.36',
}
conn.request('GET', '/feed/', headers=headers)
response = conn.getresponse()

from bs4 import BeautifulSoup

soup = BeautifulSoup(response, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="android chrome" lang="en">
# <head>
# <meta content="p_mwlite_feed" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# ...

# %%
from urllib.parse import urlparse

url = 'https://www.linkedin.com/search/results/people/?keywords=g.h.%20raisoni%20societys%2C%20college%20of%20engineering%20and%20management%2C%20pune&network=%5B%22F%22%5D&sid=FDn'
parsed_url = urlparse(url)
path = parsed_url.path
query = parsed_url.query


conn.request('GET', f'{path}?{query}', headers=headers)
response = conn.getresponse()

from bs4 import BeautifulSoup

soup = BeautifulSoup(response, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="android chrome" lang="en">
# <head>
# <meta content="p_mwlite_search_people_keyword" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# ...

# %%
spans = soup.find_all('span', class_='text-md')

names = [span.get_text(strip=True) for span in spans]
    
for name in names:
  print(name)
# Out:
# Satyendrasingh Sisodiya
# Piyush Soni
# Deepak Kumbhar
# Neha Tonape
# Aditya Lokre
# Sana Inamdar
# Prashant Patil
# Amit Jambhulkar
# Avishkar Bhandare
# Neha Wadile
